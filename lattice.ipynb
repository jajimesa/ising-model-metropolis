# %%
import numpy as np
import matplotlib.pyplot as plt

temperaturas = [4.0, 2.269, 2.0, 1.0]

def leer_configuraciones(nombre_archivo, L):
    """Lee configuraciones asumiendo L valores por línea, L líneas por configuración."""
    configuraciones = []
    valores_por_config = L * L
    valores = []
    linea_num = 0
    
    # Leer todas las líneas y extraer valores
    with open(nombre_archivo, "r") as f:
        for linea in f:
            linea = linea.strip()
            linea_num += 1
            if not linea:
                print(f"Línea {linea_num}: vacía, ignorada")
                continue
            try:
                datos = [int(x) for x in linea.split()]
                print(f"Línea {linea_num}: {len(datos)} valores")
                if len(datos) != L:
                    print(f"Error: esperados {L} valores por línea, encontrados {len(datos)} en línea {linea_num}")
                    return []
                valores.extend(datos)
            except ValueError:
                print(f"Error al leer la línea {linea_num}: {linea}")
                return []
    
    # Verificar el total de valores
    total_valores = len(valores)
    print(f"Total de valores leídos: {total_valores}")
    if total_valores % valores_por_config != 0:
        print(f"Error: el total de valores ({total_valores}) no es múltiplo de {valores_por_config}")
        return []
    
    # Crear configuraciones
    num_configs = total_valores // valores_por_config
    for i in range(num_configs):
        inicio = i * valores_por_config
        fin = inicio + valores_por_config
        config = np.array(valores[inicio:fin]).reshape(L, L)
        configuraciones.append(config)
    
    return configuraciones

def graficar_configuraciones(configuraciones, temperaturas, L):
    n_plots = min(len(configuraciones), len(temperaturas))
    fig, axs = plt.subplots(1, n_plots, figsize=(10, 3))
    if n_plots == 1:
        axs = [axs]
        
    for i, (config, T) in enumerate(zip(configuraciones[:n_plots], temperaturas[:n_plots])):
        #axs[i].imshow(config, cmap="gray", interpolation="none")
        axs[i].imshow(config, cmap="gray", interpolation="none")
        if  T!=2.269: axs[i].set_title(f"$T = {T}$")
        else: axs[i].set_title("$T = T_c$")
        axs[i].axis("off")
    
    plt.tight_layout()
    plt.savefig(fname="lattice.png", dpi=300)
    plt.show()

# %%
L = 80

ruta_archivo = "Datos/L80/fort.99"  # Ajusta la ruta si es necesario
configuraciones = leer_configuraciones(ruta_archivo, L)
if configuraciones:
    print(f"Se leyeron {len(configuraciones)} configuraciones")
    graficar_configuraciones(configuraciones, temperaturas, L)
else:
    print(f"No se pudieron leer configuraciones válidas de {ruta_archivo}.")
# Out:
# Línea 1: 80 valores
# Línea 2: 80 valores
# Línea 3: 80 valores
# Línea 4: 80 valores
# Línea 5: 80 valores
# Línea 6: 80 valores
# Línea 7: 80 valores
# Línea 8: 80 valores
# Línea 9: 80 valores
# Línea 10: 80 valores
# Línea 11: 80 valores
# Línea 12: 80 valores
# Línea 13: 80 valores
# Línea 14: 80 valores
# Línea 15: 80 valores
# Línea 16: 80 valores
# Línea 17: 80 valores
# Línea 18: 80 valores
# Línea 19: 80 valores
# Línea 20: 80 valores
# Línea 21: 80 valores
# Línea 22: 80 valores
# Línea 23: 80 valores
# Línea 24: 80 valores
# Línea 25: 80 valores
# Línea 26: 80 valores
# Línea 27: 80 valores
# Línea 28: 80 valores
# Línea 29: 80 valores
# Línea 30: 80 valores
# Línea 31: 80 valores
# Línea 32: 80 valores
# Línea 33: 80 valores
# Línea 34: 80 valores
# Línea 35: 80 valores
# Línea 36: 80 valores
# Línea 37: 80 valores
# Línea 38: 80 valores
# Línea 39: 80 valores
# Línea 40: 80 valores
# Línea 41: 80 valores
# Línea 42: 80 valores
# Línea 43: 80 valores
# Línea 44: 80 valores
# Línea 45: 80 valores
# Línea 46: 80 valores
# Línea 47: 80 valores
# Línea 48: 80 valores
# Línea 49: 80 valores
# Línea 50: 80 valores
# Línea 51: 80 valores
# Línea 52: 80 valores
# Línea 53: 80 valores
# Línea 54: 80 valores
# Línea 55: 80 valores
# Línea 56: 80 valores
# Línea 57: 80 valores
# Línea 58: 80 valores
# Línea 59: 80 valores
# Línea 60: 80 valores
# Línea 61: 80 valores
# Línea 62: 80 valores
# Línea 63: 80 valores
# Línea 64: 80 valores
# Línea 65: 80 valores
# Línea 66: 80 valores
# Línea 67: 80 valores
# Línea 68: 80 valores
# Línea 69: 80 valores
# Línea 70: 80 valores
# Línea 71: 80 valores
# Línea 72: 80 valores
# Línea 73: 80 valores
# Línea 74: 80 valores
# Línea 75: 80 valores
# Línea 76: 80 valores
# Línea 77: 80 valores
# Línea 78: 80 valores
# Línea 79: 80 valores
# Línea 80: 80 valores
# Línea 81: vacía, ignorada
# Línea 82: 80 valores
# Línea 83: 80 valores
# Línea 84: 80 valores
# Línea 85: 80 valores
# Línea 86: 80 valores
# Línea 87: 80 valores
# Línea 88: 80 valores
# Línea 89: 80 valores
# Línea 90: 80 valores
# Línea 91: 80 valores
# Línea 92: 80 valores
# Línea 93: 80 valores
# Línea 94: 80 valores
# Línea 95: 80 valores
# Línea 96: 80 valores
# Línea 97: 80 valores
# Línea 98: 80 valores
# Línea 99: 80 valores
# Línea 100: 80 valores
# Línea 101: 80 valores
# Línea 102: 80 valores
# Línea 103: 80 valores
# Línea 104: 80 valores
# Línea 105: 80 valores
# Línea 106: 80 valores
# Línea 107: 80 valores
# Línea 108: 80 valores
# Línea 109: 80 valores
# Línea 110: 80 valores
# Línea 111: 80 valores
# Línea 112: 80 valores
# Línea 113: 80 valores
# Línea 114: 80 valores
# Línea 115: 80 valores
# Línea 116: 80 valores
# Línea 117: 80 valores
# Línea 118: 80 valores
# Línea 119: 80 valores
# Línea 120: 80 valores
# Línea 121: 80 valores
# Línea 122: 80 valores
# Línea 123: 80 valores
# Línea 124: 80 valores
# Línea 125: 80 valores
# Línea 126: 80 valores
# Línea 127: 80 valores
# Línea 128: 80 valores
# Línea 129: 80 valores
# Línea 130: 80 valores
# Línea 131: 80 valores
# Línea 132: 80 valores
# Línea 133: 80 valores
# Línea 134: 80 valores
# Línea 135: 80 valores
# Línea 136: 80 valores
# Línea 137: 80 valores
# Línea 138: 80 valores
# Línea 139: 80 valores
# Línea 140: 80 valores
# Línea 141: 80 valores
# Línea 142: 80 valores
# Línea 143: 80 valores
# Línea 144: 80 valores
# Línea 145: 80 valores
# Línea 146: 80 valores
# Línea 147: 80 valores
# Línea 148: 80 valores
# Línea 149: 80 valores
# Línea 150: 80 valores
# Línea 151: 80 valores
# Línea 152: 80 valores
# Línea 153: 80 valores
# Línea 154: 80 valores
# Línea 155: 80 valores
# Línea 156: 80 valores
# Línea 157: 80 valores
# Línea 158: 80 valores
# Línea 159: 80 valores
# Línea 160: 80 valores
# Línea 161: 80 valores
# Línea 162: vacía, ignorada
# Línea 163: 80 valores
# Línea 164: 80 valores
# Línea 165: 80 valores
# Línea 166: 80 valores
# Línea 167: 80 valores
# Línea 168: 80 valores
# Línea 169: 80 valores
# Línea 170: 80 valores
# Línea 171: 80 valores
# Línea 172: 80 valores
# Línea 173: 80 valores
# Línea 174: 80 valores
# Línea 175: 80 valores
# Línea 176: 80 valores
# Línea 177: 80 valores
# Línea 178: 80 valores
# Línea 179: 80 valores
# Línea 180: 80 valores
# Línea 181: 80 valores
# Línea 182: 80 valores
# Línea 183: 80 valores
# Línea 184: 80 valores
# Línea 185: 80 valores
# Línea 186: 80 valores
# Línea 187: 80 valores
# Línea 188: 80 valores
# Línea 189: 80 valores
# Línea 190: 80 valores
# Línea 191: 80 valores
# Línea 192: 80 valores
# Línea 193: 80 valores
# Línea 194: 80 valores
# Línea 195: 80 valores
# Línea 196: 80 valores
# Línea 197: 80 valores
# Línea 198: 80 valores
# Línea 199: 80 valores
# Línea 200: 80 valores
# Línea 201: 80 valores
# Línea 202: 80 valores
# Línea 203: 80 valores
# Línea 204: 80 valores
# Línea 205: 80 valores
# Línea 206: 80 valores
# Línea 207: 80 valores
# Línea 208: 80 valores
# Línea 209: 80 valores
# Línea 210: 80 valores
# Línea 211: 80 valores
# Línea 212: 80 valores
# Línea 213: 80 valores
# Línea 214: 80 valores
# Línea 215: 80 valores
# Línea 216: 80 valores
# Línea 217: 80 valores
# Línea 218: 80 valores
# Línea 219: 80 valores
# Línea 220: 80 valores
# Línea 221: 80 valores
# Línea 222: 80 valores
# Línea 223: 80 valores
# Línea 224: 80 valores
# Línea 225: 80 valores
# Línea 226: 80 valores
# Línea 227: 80 valores
# Línea 228: 80 valores
# Línea 229: 80 valores
# Línea 230: 80 valores
# Línea 231: 80 valores
# Línea 232: 80 valores
# Línea 233: 80 valores
# Línea 234: 80 valores
# Línea 235: 80 valores
# Línea 236: 80 valores
# Línea 237: 80 valores
# Línea 238: 80 valores
# Línea 239: 80 valores
# Línea 240: 80 valores
# Línea 241: 80 valores
# Línea 242: 80 valores
# Línea 243: vacía, ignorada
# Línea 244: 80 valores
# Línea 245: 80 valores
# Línea 246: 80 valores
# Línea 247: 80 valores
# Línea 248: 80 valores
# Línea 249: 80 valores
# Línea 250: 80 valores
# Línea 251: 80 valores
# Línea 252: 80 valores
# Línea 253: 80 valores
# Línea 254: 80 valores
# Línea 255: 80 valores
# Línea 256: 80 valores
# Línea 257: 80 valores
# Línea 258: 80 valores
# Línea 259: 80 valores
# Línea 260: 80 valores
# Línea 261: 80 valores
# Línea 262: 80 valores
# Línea 263: 80 valores
# Línea 264: 80 valores
# Línea 265: 80 valores
# Línea 266: 80 valores
# Línea 267: 80 valores
# Línea 268: 80 valores
# Línea 269: 80 valores
# Línea 270: 80 valores
# Línea 271: 80 valores
# Línea 272: 80 valores
# Línea 273: 80 valores
# Línea 274: 80 valores
# Línea 275: 80 valores
# Línea 276: 80 valores
# Línea 277: 80 valores
# Línea 278: 80 valores
# Línea 279: 80 valores
# Línea 280: 80 valores
# Línea 281: 80 valores
# Línea 282: 80 valores
# Línea 283: 80 valores
# Línea 284: 80 valores
# Línea 285: 80 valores
# Línea 286: 80 valores
# Línea 287: 80 valores
# Línea 288: 80 valores
# Línea 289: 80 valores
# Línea 290: 80 valores
# Línea 291: 80 valores
# Línea 292: 80 valores
# Línea 293: 80 valores
# Línea 294: 80 valores
# Línea 295: 80 valores
# Línea 296: 80 valores
# Línea 297: 80 valores
# Línea 298: 80 valores
# Línea 299: 80 valores
# Línea 300: 80 valores
# Línea 301: 80 valores
# Línea 302: 80 valores
# Línea 303: 80 valores
# Línea 304: 80 valores
# Línea 305: 80 valores
# Línea 306: 80 valores
# Línea 307: 80 valores
# Línea 308: 80 valores
# Línea 309: 80 valores
# Línea 310: 80 valores
# Línea 311: 80 valores
# Línea 312: 80 valores
# Línea 313: 80 valores
# Línea 314: 80 valores
# Línea 315: 80 valores
# Línea 316: 80 valores
# Línea 317: 80 valores
# Línea 318: 80 valores
# Línea 319: 80 valores
# Línea 320: 80 valores
# Línea 321: 80 valores
# Línea 322: 80 valores
# Línea 323: 80 valores
# Línea 324: vacía, ignorada
# Total de valores leídos: 25600
# Se leyeron 4 configuraciones

# %%
L = 160

ruta_archivo = "Datos/L160/fort.99"  # Ajusta la ruta si es necesario
configuraciones = leer_configuraciones(ruta_archivo, L)
if configuraciones:
    print(f"Se leyeron {len(configuraciones)} configuraciones")
    graficar_configuraciones(configuraciones, temperaturas, L)
else:
    print(f"No se pudieron leer configuraciones válidas de {ruta_archivo}.")
# Out:
# Línea 1: 160 valores
# Línea 2: 160 valores
# Línea 3: 160 valores
# Línea 4: 160 valores
# Línea 5: 160 valores
# Línea 6: 160 valores
# Línea 7: 160 valores
# Línea 8: 160 valores
# Línea 9: 160 valores
# Línea 10: 160 valores
# Línea 11: 160 valores
# Línea 12: 160 valores
# Línea 13: 160 valores
# Línea 14: 160 valores
# Línea 15: 160 valores
# Línea 16: 160 valores
# Línea 17: 160 valores
# Línea 18: 160 valores
# Línea 19: 160 valores
# Línea 20: 160 valores
# Línea 21: 160 valores
# Línea 22: 160 valores
# Línea 23: 160 valores
# Línea 24: 160 valores
# Línea 25: 160 valores
# Línea 26: 160 valores
# Línea 27: 160 valores
# Línea 28: 160 valores
# Línea 29: 160 valores
# Línea 30: 160 valores
# Línea 31: 160 valores
# Línea 32: 160 valores
# Línea 33: 160 valores
# Línea 34: 160 valores
# Línea 35: 160 valores
# Línea 36: 160 valores
# Línea 37: 160 valores
# Línea 38: 160 valores
# Línea 39: 160 valores
# Línea 40: 160 valores
# Línea 41: 160 valores
# Línea 42: 160 valores
# Línea 43: 160 valores
# Línea 44: 160 valores
# Línea 45: 160 valores
# Línea 46: 160 valores
# Línea 47: 160 valores
# Línea 48: 160 valores
# Línea 49: 160 valores
# Línea 50: 160 valores
# Línea 51: 160 valores
# Línea 52: 160 valores
# Línea 53: 160 valores
# Línea 54: 160 valores
# Línea 55: 160 valores
# Línea 56: 160 valores
# Línea 57: 160 valores
# Línea 58: 160 valores
# Línea 59: 160 valores
# Línea 60: 160 valores
# Línea 61: 160 valores
# Línea 62: 160 valores
# Línea 63: 160 valores
# Línea 64: 160 valores
# Línea 65: 160 valores
# Línea 66: 160 valores
# Línea 67: 160 valores
# Línea 68: 160 valores
# Línea 69: 160 valores
# Línea 70: 160 valores
# Línea 71: 160 valores
# Línea 72: 160 valores
# Línea 73: 160 valores
# Línea 74: 160 valores
# Línea 75: 160 valores
# Línea 76: 160 valores
# Línea 77: 160 valores
# Línea 78: 160 valores
# Línea 79: 160 valores
# Línea 80: 160 valores
# Línea 81: 160 valores
# Línea 82: 160 valores
# Línea 83: 160 valores
# Línea 84: 160 valores
# Línea 85: 160 valores
# Línea 86: 160 valores
# Línea 87: 160 valores
# Línea 88: 160 valores
# Línea 89: 160 valores
# Línea 90: 160 valores
# Línea 91: 160 valores
# Línea 92: 160 valores
# Línea 93: 160 valores
# Línea 94: 160 valores
# Línea 95: 160 valores
# Línea 96: 160 valores
# Línea 97: 160 valores
# Línea 98: 160 valores
# Línea 99: 160 valores
# Línea 100: 160 valores
# Línea 101: 160 valores
# Línea 102: 160 valores
# Línea 103: 160 valores
# Línea 104: 160 valores
# Línea 105: 160 valores
# Línea 106: 160 valores
# Línea 107: 160 valores
# Línea 108: 160 valores
# Línea 109: 160 valores
# Línea 110: 160 valores
# Línea 111: 160 valores
# Línea 112: 160 valores
# Línea 113: 160 valores
# Línea 114: 160 valores
# Línea 115: 160 valores
# Línea 116: 160 valores
# Línea 117: 160 valores
# Línea 118: 160 valores
# Línea 119: 160 valores
# Línea 120: 160 valores
# Línea 121: 160 valores
# Línea 122: 160 valores
# Línea 123: 160 valores
# Línea 124: 160 valores
# Línea 125: 160 valores
# Línea 126: 160 valores
# Línea 127: 160 valores
# Línea 128: 160 valores
# Línea 129: 160 valores
# Línea 130: 160 valores
# Línea 131: 160 valores
# Línea 132: 160 valores
# Línea 133: 160 valores
# Línea 134: 160 valores
# Línea 135: 160 valores
# Línea 136: 160 valores
# Línea 137: 160 valores
# Línea 138: 160 valores
# Línea 139: 160 valores
# Línea 140: 160 valores
# Línea 141: 160 valores
# Línea 142: 160 valores
# Línea 143: 160 valores
# Línea 144: 160 valores
# Línea 145: 160 valores
# Línea 146: 160 valores
# Línea 147: 160 valores
# Línea 148: 160 valores
# Línea 149: 160 valores
# Línea 150: 160 valores
# Línea 151: 160 valores
# Línea 152: 160 valores
# Línea 153: 160 valores
# Línea 154: 160 valores
# Línea 155: 160 valores
# Línea 156: 160 valores
# Línea 157: 160 valores
# Línea 158: 160 valores
# Línea 159: 160 valores
# Línea 160: 160 valores
# Línea 161: vacía, ignorada
# Línea 162: 160 valores
# Línea 163: 160 valores
# Línea 164: 160 valores
# Línea 165: 160 valores
# Línea 166: 160 valores
# Línea 167: 160 valores
# Línea 168: 160 valores
# Línea 169: 160 valores
# Línea 170: 160 valores
# Línea 171: 160 valores
# Línea 172: 160 valores
# Línea 173: 160 valores
# Línea 174: 160 valores
# Línea 175: 160 valores
# Línea 176: 160 valores
# Línea 177: 160 valores
# Línea 178: 160 valores
# Línea 179: 160 valores
# Línea 180: 160 valores
# Línea 181: 160 valores
# Línea 182: 160 valores
# Línea 183: 160 valores
# Línea 184: 160 valores
# Línea 185: 160 valores
# Línea 186: 160 valores
# Línea 187: 160 valores
# Línea 188: 160 valores
# Línea 189: 160 valores
# Línea 190: 160 valores
# Línea 191: 160 valores
# Línea 192: 160 valores
# Línea 193: 160 valores
# Línea 194: 160 valores
# Línea 195: 160 valores
# Línea 196: 160 valores
# Línea 197: 160 valores
# Línea 198: 160 valores
# Línea 199: 160 valores
# Línea 200: 160 valores
# Línea 201: 160 valores
# Línea 202: 160 valores
# Línea 203: 160 valores
# Línea 204: 160 valores
# Línea 205: 160 valores
# Línea 206: 160 valores
# Línea 207: 160 valores
# Línea 208: 160 valores
# Línea 209: 160 valores
# Línea 210: 160 valores
# Línea 211: 160 valores
# Línea 212: 160 valores
# Línea 213: 160 valores
# Línea 214: 160 valores
# Línea 215: 160 valores
# Línea 216: 160 valores
# Línea 217: 160 valores
# Línea 218: 160 valores
# Línea 219: 160 valores
# Línea 220: 160 valores
# Línea 221: 160 valores
# Línea 222: 160 valores
# Línea 223: 160 valores
# Línea 224: 160 valores
# Línea 225: 160 valores
# Línea 226: 160 valores
# Línea 227: 160 valores
# Línea 228: 160 valores
# Línea 229: 160 valores
# Línea 230: 160 valores
# Línea 231: 160 valores
# Línea 232: 160 valores
# Línea 233: 160 valores
# Línea 234: 160 valores
# Línea 235: 160 valores
# Línea 236: 160 valores
# Línea 237: 160 valores
# Línea 238: 160 valores
# Línea 239: 160 valores
# Línea 240: 160 valores
# Línea 241: 160 valores
# Línea 242: 160 valores
# Línea 243: 160 valores
# Línea 244: 160 valores
# Línea 245: 160 valores
# Línea 246: 160 valores
# Línea 247: 160 valores
# Línea 248: 160 valores
# Línea 249: 160 valores
# Línea 250: 160 valores
# Línea 251: 160 valores
# Línea 252: 160 valores
# Línea 253: 160 valores
# Línea 254: 160 valores
# Línea 255: 160 valores
# Línea 256: 160 valores
# Línea 257: 160 valores
# Línea 258: 160 valores
# Línea 259: 160 valores
# Línea 260: 160 valores
# Línea 261: 160 valores
# Línea 262: 160 valores
# Línea 263: 160 valores
# Línea 264: 160 valores
# Línea 265: 160 valores
# Línea 266: 160 valores
# Línea 267: 160 valores
# Línea 268: 160 valores
# Línea 269: 160 valores
# Línea 270: 160 valores
# Línea 271: 160 valores
# Línea 272: 160 valores
# Línea 273: 160 valores
# Línea 274: 160 valores
# Línea 275: 160 valores
# Línea 276: 160 valores
# Línea 277: 160 valores
# Línea 278: 160 valores
# Línea 279: 160 valores
# Línea 280: 160 valores
# Línea 281: 160 valores
# Línea 282: 160 valores
# Línea 283: 160 valores
# Línea 284: 160 valores
# Línea 285: 160 valores
# Línea 286: 160 valores
# Línea 287: 160 valores
# Línea 288: 160 valores
# Línea 289: 160 valores
# Línea 290: 160 valores
# Línea 291: 160 valores
# Línea 292: 160 valores
# Línea 293: 160 valores
# Línea 294: 160 valores
# Línea 295: 160 valores
# Línea 296: 160 valores
# Línea 297: 160 valores
# Línea 298: 160 valores
# Línea 299: 160 valores
# Línea 300: 160 valores
# Línea 301: 160 valores
# Línea 302: 160 valores
# Línea 303: 160 valores
# Línea 304: 160 valores
# Línea 305: 160 valores
# Línea 306: 160 valores
# Línea 307: 160 valores
# Línea 308: 160 valores
# Línea 309: 160 valores
# Línea 310: 160 valores
# Línea 311: 160 valores
# Línea 312: 160 valores
# Línea 313: 160 valores
# Línea 314: 160 valores
# Línea 315: 160 valores
# Línea 316: 160 valores
# Línea 317: 160 valores
# Línea 318: 160 valores
# Línea 319: 160 valores
# Línea 320: 160 valores
# Línea 321: 160 valores
# Línea 322: vacía, ignorada
# Línea 323: 160 valores
# Línea 324: 160 valores
# Línea 325: 160 valores
# Línea 326: 160 valores
# Línea 327: 160 valores
# Línea 328: 160 valores
# Línea 329: 160 valores
# Línea 330: 160 valores
# Línea 331: 160 valores
# Línea 332: 160 valores
# Línea 333: 160 valores
# Línea 334: 160 valores
# Línea 335: 160 valores
# Línea 336: 160 valores
# Línea 337: 160 valores
# Línea 338: 160 valores
# Línea 339: 160 valores
# Línea 340: 160 valores
# Línea 341: 160 valores
# Línea 342: 160 valores
# Línea 343: 160 valores
# Línea 344: 160 valores
# Línea 345: 160 valores
# Línea 346: 160 valores
# Línea 347: 160 valores
# Línea 348: 160 valores
# Línea 349: 160 valores
# Línea 350: 160 valores
# Línea 351: 160 valores
# Línea 352: 160 valores
# Línea 353: 160 valores
# Línea 354: 160 valores
# Línea 355: 160 valores
# Línea 356: 160 valores
# Línea 357: 160 valores
# Línea 358: 160 valores
# Línea 359: 160 valores
# Línea 360: 160 valores
# Línea 361: 160 valores
# Línea 362: 160 valores
# Línea 363: 160 valores
# Línea 364: 160 valores
# Línea 365: 160 valores
# Línea 366: 160 valores
# Línea 367: 160 valores
# Línea 368: 160 valores
# Línea 369: 160 valores
# Línea 370: 160 valores
# Línea 371: 160 valores
# Línea 372: 160 valores
# Línea 373: 160 valores
# Línea 374: 160 valores
# Línea 375: 160 valores
# Línea 376: 160 valores
# Línea 377: 160 valores
# Línea 378: 160 valores
# Línea 379: 160 valores
# Línea 380: 160 valores
# Línea 381: 160 valores
# Línea 382: 160 valores
# Línea 383: 160 valores
# Línea 384: 160 valores
# Línea 385: 160 valores
# Línea 386: 160 valores
# Línea 387: 160 valores
# Línea 388: 160 valores
# Línea 389: 160 valores
# Línea 390: 160 valores
# Línea 391: 160 valores
# Línea 392: 160 valores
# Línea 393: 160 valores
# Línea 394: 160 valores
# Línea 395: 160 valores
# Línea 396: 160 valores
# Línea 397: 160 valores
# Línea 398: 160 valores
# Línea 399: 160 valores
# Línea 400: 160 valores
# Línea 401: 160 valores
# Línea 402: 160 valores
# Línea 403: 160 valores
# Línea 404: 160 valores
# Línea 405: 160 valores
# Línea 406: 160 valores
# Línea 407: 160 valores
# Línea 408: 160 valores
# Línea 409: 160 valores
# Línea 410: 160 valores
# Línea 411: 160 valores
# Línea 412: 160 valores
# Línea 413: 160 valores
# Línea 414: 160 valores
# Línea 415: 160 valores
# Línea 416: 160 valores
# Línea 417: 160 valores
# Línea 418: 160 valores
# Línea 419: 160 valores
# Línea 420: 160 valores
# Línea 421: 160 valores
# Línea 422: 160 valores
# Línea 423: 160 valores
# Línea 424: 160 valores
# Línea 425: 160 valores
# Línea 426: 160 valores
# Línea 427: 160 valores
# Línea 428: 160 valores
# Línea 429: 160 valores
# Línea 430: 160 valores
# Línea 431: 160 valores
# Línea 432: 160 valores
# Línea 433: 160 valores
# Línea 434: 160 valores
# Línea 435: 160 valores
# Línea 436: 160 valores
# Línea 437: 160 valores
# Línea 438: 160 valores
# Línea 439: 160 valores
# Línea 440: 160 valores
# Línea 441: 160 valores
# Línea 442: 160 valores
# Línea 443: 160 valores
# Línea 444: 160 valores
# Línea 445: 160 valores
# Línea 446: 160 valores
# Línea 447: 160 valores
# Línea 448: 160 valores
# Línea 449: 160 valores
# Línea 450: 160 valores
# Línea 451: 160 valores
# Línea 452: 160 valores
# Línea 453: 160 valores
# Línea 454: 160 valores
# Línea 455: 160 valores
# Línea 456: 160 valores
# Línea 457: 160 valores
# Línea 458: 160 valores
# Línea 459: 160 valores
# Línea 460: 160 valores
# Línea 461: 160 valores
# Línea 462: 160 valores
# Línea 463: 160 valores
# Línea 464: 160 valores
# Línea 465: 160 valores
# Línea 466: 160 valores
# Línea 467: 160 valores
# Línea 468: 160 valores
# Línea 469: 160 valores
# Línea 470: 160 valores
# Línea 471: 160 valores
# Línea 472: 160 valores
# Línea 473: 160 valores
# Línea 474: 160 valores
# Línea 475: 160 valores
# Línea 476: 160 valores
# Línea 477: 160 valores
# Línea 478: 160 valores
# Línea 479: 160 valores
# Línea 480: 160 valores
# Línea 481: 160 valores
# Línea 482: 160 valores
# Línea 483: vacía, ignorada
# Línea 484: 160 valores
# Línea 485: 160 valores
# Línea 486: 160 valores
# Línea 487: 160 valores
# Línea 488: 160 valores
# Línea 489: 160 valores
# Línea 490: 160 valores
# Línea 491: 160 valores
# Línea 492: 160 valores
# Línea 493: 160 valores
# Línea 494: 160 valores
# Línea 495: 160 valores
# Línea 496: 160 valores
# Línea 497: 160 valores
# Línea 498: 160 valores
# Línea 499: 160 valores
# Línea 500: 160 valores
# Línea 501: 160 valores
# Línea 502: 160 valores
# Línea 503: 160 valores
# Línea 504: 160 valores
# Línea 505: 160 valores
# Línea 506: 160 valores
# Línea 507: 160 valores
# Línea 508: 160 valores
# Línea 509: 160 valores
# Línea 510: 160 valores
# Línea 511: 160 valores
# Línea 512: 160 valores
# Línea 513: 160 valores
# Línea 514: 160 valores
# Línea 515: 160 valores
# Línea 516: 160 valores
# Línea 517: 160 valores
# Línea 518: 160 valores
# Línea 519: 160 valores
# Línea 520: 160 valores
# Línea 521: 160 valores
# Línea 522: 160 valores
# Línea 523: 160 valores
# Línea 524: 160 valores
# Línea 525: 160 valores
# Línea 526: 160 valores
# Línea 527: 160 valores
# Línea 528: 160 valores
# Línea 529: 160 valores
# Línea 530: 160 valores
# Línea 531: 160 valores
# Línea 532: 160 valores
# Línea 533: 160 valores
# Línea 534: 160 valores
# Línea 535: 160 valores
# Línea 536: 160 valores
# Línea 537: 160 valores
# Línea 538: 160 valores
# Línea 539: 160 valores
# Línea 540: 160 valores
# Línea 541: 160 valores
# Línea 542: 160 valores
# Línea 543: 160 valores
# Línea 544: 160 valores
# Línea 545: 160 valores
# Línea 546: 160 valores
# Línea 547: 160 valores
# Línea 548: 160 valores
# Línea 549: 160 valores
# Línea 550: 160 valores
# Línea 551: 160 valores
# Línea 552: 160 valores
# Línea 553: 160 valores
# Línea 554: 160 valores
# Línea 555: 160 valores
# Línea 556: 160 valores
# Línea 557: 160 valores
# Línea 558: 160 valores
# Línea 559: 160 valores
# Línea 560: 160 valores
# Línea 561: 160 valores
# Línea 562: 160 valores
# Línea 563: 160 valores
# Línea 564: 160 valores
# Línea 565: 160 valores
# Línea 566: 160 valores
# Línea 567: 160 valores
# Línea 568: 160 valores
# Línea 569: 160 valores
# Línea 570: 160 valores
# Línea 571: 160 valores
# Línea 572: 160 valores
# Línea 573: 160 valores
# Línea 574: 160 valores
# Línea 575: 160 valores
# Línea 576: 160 valores
# Línea 577: 160 valores
# Línea 578: 160 valores
# Línea 579: 160 valores
# Línea 580: 160 valores
# Línea 581: 160 valores
# Línea 582: 160 valores
# Línea 583: 160 valores
# Línea 584: 160 valores
# Línea 585: 160 valores
# Línea 586: 160 valores
# Línea 587: 160 valores
# Línea 588: 160 valores
# Línea 589: 160 valores
# Línea 590: 160 valores
# Línea 591: 160 valores
# Línea 592: 160 valores
# Línea 593: 160 valores
# Línea 594: 160 valores
# Línea 595: 160 valores
# Línea 596: 160 valores
# Línea 597: 160 valores
# Línea 598: 160 valores
# Línea 599: 160 valores
# Línea 600: 160 valores
# Línea 601: 160 valores
# Línea 602: 160 valores
# Línea 603: 160 valores
# Línea 604: 160 valores
# Línea 605: 160 valores
# Línea 606: 160 valores
# Línea 607: 160 valores
# Línea 608: 160 valores
# Línea 609: 160 valores
# Línea 610: 160 valores
# Línea 611: 160 valores
# Línea 612: 160 valores
# Línea 613: 160 valores
# Línea 614: 160 valores
# Línea 615: 160 valores
# Línea 616: 160 valores
# Línea 617: 160 valores
# Línea 618: 160 valores
# Línea 619: 160 valores
# Línea 620: 160 valores
# Línea 621: 160 valores
# Línea 622: 160 valores
# Línea 623: 160 valores
# Línea 624: 160 valores
# Línea 625: 160 valores
# Línea 626: 160 valores
# Línea 627: 160 valores
# Línea 628: 160 valores
# Línea 629: 160 valores
# Línea 630: 160 valores
# Línea 631: 160 valores
# Línea 632: 160 valores
# Línea 633: 160 valores
# Línea 634: 160 valores
# Línea 635: 160 valores
# Línea 636: 160 valores
# Línea 637: 160 valores
# Línea 638: 160 valores
# Línea 639: 160 valores
# Línea 640: 160 valores
# Línea 641: 160 valores
# Línea 642: 160 valores
# Línea 643: 160 valores
# Línea 644: vacía, ignorada
# Total de valores leídos: 102400
# Se leyeron 4 configuraciones

# %%
L = 320

ruta_archivo = "Datos/L320/fort.99"  # Ajusta la ruta si es necesario
configuraciones = leer_configuraciones(ruta_archivo, L)
if configuraciones:
    print(f"Se leyeron {len(configuraciones)} configuraciones")
    graficar_configuraciones(configuraciones, temperaturas, L)
else:
    print(f"No se pudieron leer configuraciones válidas de {ruta_archivo}.")
# Out:
# Línea 1: 320 valores
# Línea 2: 320 valores
# Línea 3: 320 valores
# Línea 4: 320 valores
# Línea 5: 320 valores
# Línea 6: 320 valores
# Línea 7: 320 valores
# Línea 8: 320 valores
# Línea 9: 320 valores
# Línea 10: 320 valores
# Línea 11: 320 valores
# Línea 12: 320 valores
# Línea 13: 320 valores
# Línea 14: 320 valores
# Línea 15: 320 valores
# Línea 16: 320 valores
# Línea 17: 320 valores
# Línea 18: 320 valores
# Línea 19: 320 valores
# Línea 20: 320 valores
# Línea 21: 320 valores
# Línea 22: 320 valores
# Línea 23: 320 valores
# Línea 24: 320 valores
# Línea 25: 320 valores
# Línea 26: 320 valores
# Línea 27: 320 valores
# Línea 28: 320 valores
# Línea 29: 320 valores
# Línea 30: 320 valores
# Línea 31: 320 valores
# Línea 32: 320 valores
# Línea 33: 320 valores
# Línea 34: 320 valores
# Línea 35: 320 valores
# Línea 36: 320 valores
# Línea 37: 320 valores
# Línea 38: 320 valores
# Línea 39: 320 valores
# Línea 40: 320 valores
# Línea 41: 320 valores
# Línea 42: 320 valores
# Línea 43: 320 valores
# Línea 44: 320 valores
# Línea 45: 320 valores
# Línea 46: 320 valores
# Línea 47: 320 valores
# Línea 48: 320 valores
# Línea 49: 320 valores
# Línea 50: 320 valores
# Línea 51: 320 valores
# Línea 52: 320 valores
# Línea 53: 320 valores
# Línea 54: 320 valores
# Línea 55: 320 valores
# Línea 56: 320 valores
# Línea 57: 320 valores
# Línea 58: 320 valores
# Línea 59: 320 valores
# Línea 60: 320 valores
# Línea 61: 320 valores
# Línea 62: 320 valores
# Línea 63: 320 valores
# Línea 64: 320 valores
# Línea 65: 320 valores
# Línea 66: 320 valores
# Línea 67: 320 valores
# Línea 68: 320 valores
# Línea 69: 320 valores
# Línea 70: 320 valores
# Línea 71: 320 valores
# Línea 72: 320 valores
# Línea 73: 320 valores
# Línea 74: 320 valores
# Línea 75: 320 valores
# Línea 76: 320 valores
# Línea 77: 320 valores
# Línea 78: 320 valores
# Línea 79: 320 valores
# Línea 80: 320 valores
# Línea 81: 320 valores
# Línea 82: 320 valores
# Línea 83: 320 valores
# Línea 84: 320 valores
# Línea 85: 320 valores
# Línea 86: 320 valores
# Línea 87: 320 valores
# Línea 88: 320 valores
# Línea 89: 320 valores
# Línea 90: 320 valores
# Línea 91: 320 valores
# Línea 92: 320 valores
# Línea 93: 320 valores
# Línea 94: 320 valores
# Línea 95: 320 valores
# Línea 96: 320 valores
# Línea 97: 320 valores
# Línea 98: 320 valores
# Línea 99: 320 valores
# Línea 100: 320 valores
# Línea 101: 320 valores
# Línea 102: 320 valores
# Línea 103: 320 valores
# Línea 104: 320 valores
# Línea 105: 320 valores
# Línea 106: 320 valores
# Línea 107: 320 valores
# Línea 108: 320 valores
# Línea 109: 320 valores
# Línea 110: 320 valores
# Línea 111: 320 valores
# Línea 112: 320 valores
# Línea 113: 320 valores
# Línea 114: 320 valores
# Línea 115: 320 valores
# Línea 116: 320 valores
# Línea 117: 320 valores
# Línea 118: 320 valores
# Línea 119: 320 valores
# Línea 120: 320 valores
# Línea 121: 320 valores
# Línea 122: 320 valores
# Línea 123: 320 valores
# Línea 124: 320 valores
# Línea 125: 320 valores
# Línea 126: 320 valores
# Línea 127: 320 valores
# Línea 128: 320 valores
# Línea 129: 320 valores
# Línea 130: 320 valores
# Línea 131: 320 valores
# Línea 132: 320 valores
# Línea 133: 320 valores
# Línea 134: 320 valores
# Línea 135: 320 valores
# Línea 136: 320 valores
# Línea 137: 320 valores
# Línea 138: 320 valores
# Línea 139: 320 valores
# Línea 140: 320 valores
# Línea 141: 320 valores
# Línea 142: 320 valores
# Línea 143: 320 valores
# Línea 144: 320 valores
# Línea 145: 320 valores
# Línea 146: 320 valores
# Línea 147: 320 valores
# Línea 148: 320 valores
# Línea 149: 320 valores
# Línea 150: 320 valores
# Línea 151: 320 valores
# Línea 152: 320 valores
# Línea 153: 320 valores
# Línea 154: 320 valores
# Línea 155: 320 valores
# Línea 156: 320 valores
# Línea 157: 320 valores
# Línea 158: 320 valores
# Línea 159: 320 valores
# Línea 160: 320 valores
# Línea 161: 320 valores
# Línea 162: 320 valores
# Línea 163: 320 valores
# Línea 164: 320 valores
# Línea 165: 320 valores
# Línea 166: 320 valores
# Línea 167: 320 valores
# Línea 168: 320 valores
# Línea 169: 320 valores
# Línea 170: 320 valores
# Línea 171: 320 valores
# Línea 172: 320 valores
# Línea 173: 320 valores
# Línea 174: 320 valores
# Línea 175: 320 valores
# Línea 176: 320 valores
# Línea 177: 320 valores
# Línea 178: 320 valores
# Línea 179: 320 valores
# Línea 180: 320 valores
# Línea 181: 320 valores
# Línea 182: 320 valores
# Línea 183: 320 valores
# Línea 184: 320 valores
# Línea 185: 320 valores
# Línea 186: 320 valores
# Línea 187: 320 valores
# Línea 188: 320 valores
# Línea 189: 320 valores
# Línea 190: 320 valores
# Línea 191: 320 valores
# Línea 192: 320 valores
# Línea 193: 320 valores
# Línea 194: 320 valores
# Línea 195: 320 valores
# Línea 196: 320 valores
# Línea 197: 320 valores
# Línea 198: 320 valores
# Línea 199: 320 valores
# Línea 200: 320 valores
# Línea 201: 320 valores
# Línea 202: 320 valores
# Línea 203: 320 valores
# Línea 204: 320 valores
# Línea 205: 320 valores
# Línea 206: 320 valores
# Línea 207: 320 valores
# Línea 208: 320 valores
# Línea 209: 320 valores
# Línea 210: 320 valores
# Línea 211: 320 valores
# Línea 212: 320 valores
# Línea 213: 320 valores
# Línea 214: 320 valores
# Línea 215: 320 valores
# Línea 216: 320 valores
# Línea 217: 320 valores
# Línea 218: 320 valores
# Línea 219: 320 valores
# Línea 220: 320 valores
# Línea 221: 320 valores
# Línea 222: 320 valores
# Línea 223: 320 valores
# Línea 224: 320 valores
# Línea 225: 320 valores
# Línea 226: 320 valores
# Línea 227: 320 valores
# Línea 228: 320 valores
# Línea 229: 320 valores
# Línea 230: 320 valores
# Línea 231: 320 valores
# Línea 232: 320 valores
# Línea 233: 320 valores
# Línea 234: 320 valores
# Línea 235: 320 valores
# Línea 236: 320 valores
# Línea 237: 320 valores
# Línea 238: 320 valores
# Línea 239: 320 valores
# Línea 240: 320 valores
# Línea 241: 320 valores
# Línea 242: 320 valores
# Línea 243: 320 valores
# Línea 244: 320 valores
# Línea 245: 320 valores
# Línea 246: 320 valores
# Línea 247: 320 valores
# Línea 248: 320 valores
# Línea 249: 320 valores
# Línea 250: 320 valores
# Línea 251: 320 valores
# Línea 252: 320 valores
# Línea 253: 320 valores
# Línea 254: 320 valores
# Línea 255: 320 valores
# Línea 256: 320 valores
# Línea 257: 320 valores
# Línea 258: 320 valores
# Línea 259: 320 valores
# Línea 260: 320 valores
# Línea 261: 320 valores
# Línea 262: 320 valores
# Línea 263: 320 valores
# Línea 264: 320 valores
# Línea 265: 320 valores
# Línea 266: 320 valores
# Línea 267: 320 valores
# Línea 268: 320 valores
# Línea 269: 320 valores
# Línea 270: 320 valores
# Línea 271: 320 valores
# Línea 272: 320 valores
# Línea 273: 320 valores
# Línea 274: 320 valores
# Línea 275: 320 valores
# Línea 276: 320 valores
# Línea 277: 320 valores
# Línea 278: 320 valores
# Línea 279: 320 valores
# Línea 280: 320 valores
# Línea 281: 320 valores
# Línea 282: 320 valores
# Línea 283: 320 valores
# Línea 284: 320 valores
# Línea 285: 320 valores
# Línea 286: 320 valores
# Línea 287: 320 valores
# Línea 288: 320 valores
# Línea 289: 320 valores
# Línea 290: 320 valores
# Línea 291: 320 valores
# Línea 292: 320 valores
# Línea 293: 320 valores
# Línea 294: 320 valores
# Línea 295: 320 valores
# Línea 296: 320 valores
# Línea 297: 320 valores
# Línea 298: 320 valores
# Línea 299: 320 valores
# Línea 300: 320 valores
# Línea 301: 320 valores
# Línea 302: 320 valores
# Línea 303: 320 valores
# Línea 304: 320 valores
# Línea 305: 320 valores
# Línea 306: 320 valores
# Línea 307: 320 valores
# Línea 308: 320 valores
# Línea 309: 320 valores
# Línea 310: 320 valores
# Línea 311: 320 valores
# Línea 312: 320 valores
# Línea 313: 320 valores
# Línea 314: 320 valores
# Línea 315: 320 valores
# Línea 316: 320 valores
# Línea 317: 320 valores
# Línea 318: 320 valores
# Línea 319: 320 valores
# Línea 320: 320 valores
# Línea 321: vacía, ignorada
# Línea 322: 320 valores
# Línea 323: 320 valores
# Línea 324: 320 valores
# Línea 325: 320 valores
# Línea 326: 320 valores
# Línea 327: 320 valores
# Línea 328: 320 valores
# Línea 329: 320 valores
# Línea 330: 320 valores
# Línea 331: 320 valores
# Línea 332: 320 valores
# Línea 333: 320 valores
# Línea 334: 320 valores
# Línea 335: 320 valores
# Línea 336: 320 valores
# Línea 337: 320 valores
# Línea 338: 320 valores
# Línea 339: 320 valores
# Línea 340: 320 valores
# Línea 341: 320 valores
# Línea 342: 320 valores
# Línea 343: 320 valores
# Línea 344: 320 valores
# Línea 345: 320 valores
# Línea 346: 320 valores
# Línea 347: 320 valores
# Línea 348: 320 valores
# Línea 349: 320 valores
# Línea 350: 320 valores
# Línea 351: 320 valores
# Línea 352: 320 valores
# Línea 353: 320 valores
# Línea 354: 320 valores
# Línea 355: 320 valores
# Línea 356: 320 valores
# Línea 357: 320 valores
# Línea 358: 320 valores
# Línea 359: 320 valores
# Línea 360: 320 valores
# Línea 361: 320 valores
# Línea 362: 320 valores
# Línea 363: 320 valores
# Línea 364: 320 valores
# Línea 365: 320 valores
# Línea 366: 320 valores
# Línea 367: 320 valores
# Línea 368: 320 valores
# Línea 369: 320 valores
# Línea 370: 320 valores
# Línea 371: 320 valores
# Línea 372: 320 valores
# Línea 373: 320 valores
# Línea 374: 320 valores
# Línea 375: 320 valores
# Línea 376: 320 valores
# Línea 377: 320 valores
# Línea 378: 320 valores
# Línea 379: 320 valores
# Línea 380: 320 valores
# Línea 381: 320 valores
# Línea 382: 320 valores
# Línea 383: 320 valores
# Línea 384: 320 valores
# Línea 385: 320 valores
# Línea 386: 320 valores
# Línea 387: 320 valores
# Línea 388: 320 valores
# Línea 389: 320 valores
# Línea 390: 320 valores
# Línea 391: 320 valores
# Línea 392: 320 valores
# Línea 393: 320 valores
# Línea 394: 320 valores
# Línea 395: 320 valores
# Línea 396: 320 valores
# Línea 397: 320 valores
# Línea 398: 320 valores
# Línea 399: 320 valores
# Línea 400: 320 valores
# Línea 401: 320 valores
# Línea 402: 320 valores
# Línea 403: 320 valores
# Línea 404: 320 valores
# Línea 405: 320 valores
# Línea 406: 320 valores
# Línea 407: 320 valores
# Línea 408: 320 valores
# Línea 409: 320 valores
# Línea 410: 320 valores
# Línea 411: 320 valores
# Línea 412: 320 valores
# Línea 413: 320 valores
# Línea 414: 320 valores
# Línea 415: 320 valores
# Línea 416: 320 valores
# Línea 417: 320 valores
# Línea 418: 320 valores
# Línea 419: 320 valores
# Línea 420: 320 valores
# Línea 421: 320 valores
# Línea 422: 320 valores
# Línea 423: 320 valores
# Línea 424: 320 valores
# Línea 425: 320 valores
# Línea 426: 320 valores
# Línea 427: 320 valores
# Línea 428: 320 valores
# Línea 429: 320 valores
# Línea 430: 320 valores
# Línea 431: 320 valores
# Línea 432: 320 valores
# Línea 433: 320 valores
# Línea 434: 320 valores
# Línea 435: 320 valores
# Línea 436: 320 valores
# Línea 437: 320 valores
# Línea 438: 320 valores
# Línea 439: 320 valores
# Línea 440: 320 valores
# Línea 441: 320 valores
# Línea 442: 320 valores
# Línea 443: 320 valores
# Línea 444: 320 valores
# Línea 445: 320 valores
# Línea 446: 320 valores
# Línea 447: 320 valores
# Línea 448: 320 valores
# Línea 449: 320 valores
# Línea 450: 320 valores
# Línea 451: 320 valores
# Línea 452: 320 valores
# Línea 453: 320 valores
# Línea 454: 320 valores
# Línea 455: 320 valores
# Línea 456: 320 valores
# Línea 457: 320 valores
# Línea 458: 320 valores
# Línea 459: 320 valores
# Línea 460: 320 valores
# Línea 461: 320 valores
# Línea 462: 320 valores
# Línea 463: 320 valores
# Línea 464: 320 valores
# Línea 465: 320 valores
# Línea 466: 320 valores
# Línea 467: 320 valores
# Línea 468: 320 valores
# Línea 469: 320 valores
# Línea 470: 320 valores
# Línea 471: 320 valores
# Línea 472: 320 valores
# Línea 473: 320 valores
# Línea 474: 320 valores
# Línea 475: 320 valores
# Línea 476: 320 valores
# Línea 477: 320 valores
# Línea 478: 320 valores
# Línea 479: 320 valores
# Línea 480: 320 valores
# Línea 481: 320 valores
# Línea 482: 320 valores
# Línea 483: 320 valores
# Línea 484: 320 valores
# Línea 485: 320 valores
# Línea 486: 320 valores
# Línea 487: 320 valores
# Línea 488: 320 valores
# Línea 489: 320 valores
# Línea 490: 320 valores
# Línea 491: 320 valores
# Línea 492: 320 valores
# Línea 493: 320 valores
# Línea 494: 320 valores
# Línea 495: 320 valores
# Línea 496: 320 valores
# Línea 497: 320 valores
# Línea 498: 320 valores
# Línea 499: 320 valores
# Línea 500: 320 valores
# Línea 501: 320 valores
# Línea 502: 320 valores
# Línea 503: 320 valores
# Línea 504: 320 valores
# Línea 505: 320 valores
# Línea 506: 320 valores
# Línea 507: 320 valores
# Línea 508: 320 valores
# Línea 509: 320 valores
# Línea 510: 320 valores
# Línea 511: 320 valores
# Línea 512: 320 valores
# Línea 513: 320 valores
# Línea 514: 320 valores
# Línea 515: 320 valores
# Línea 516: 320 valores
# Línea 517: 320 valores
# Línea 518: 320 valores
# Línea 519: 320 valores
# Línea 520: 320 valores
# Línea 521: 320 valores
# Línea 522: 320 valores
# Línea 523: 320 valores
# Línea 524: 320 valores
# Línea 525: 320 valores
# Línea 526: 320 valores
# Línea 527: 320 valores
# Línea 528: 320 valores
# Línea 529: 320 valores
# Línea 530: 320 valores
# Línea 531: 320 valores
# Línea 532: 320 valores
# Línea 533: 320 valores
# Línea 534: 320 valores
# Línea 535: 320 valores
# Línea 536: 320 valores
# Línea 537: 320 valores
# Línea 538: 320 valores
# Línea 539: 320 valores
# Línea 540: 320 valores
# Línea 541: 320 valores
# Línea 542: 320 valores
# Línea 543: 320 valores
# Línea 544: 320 valores
# Línea 545: 320 valores
# Línea 546: 320 valores
# Línea 547: 320 valores
# Línea 548: 320 valores
# Línea 549: 320 valores
# Línea 550: 320 valores
# Línea 551: 320 valores
# Línea 552: 320 valores
# Línea 553: 320 valores
# Línea 554: 320 valores
# Línea 555: 320 valores
# Línea 556: 320 valores
# Línea 557: 320 valores
# Línea 558: 320 valores
# Línea 559: 320 valores
# Línea 560: 320 valores
# Línea 561: 320 valores
# Línea 562: 320 valores
# Línea 563: 320 valores
# Línea 564: 320 valores
# Línea 565: 320 valores
# Línea 566: 320 valores
# Línea 567: 320 valores
# Línea 568: 320 valores
# Línea 569: 320 valores
# Línea 570: 320 valores
# Línea 571: 320 valores
# Línea 572: 320 valores
# Línea 573: 320 valores
# Línea 574: 320 valores
# Línea 575: 320 valores
# Línea 576: 320 valores
# Línea 577: 320 valores
# Línea 578: 320 valores
# Línea 579: 320 valores
# Línea 580: 320 valores
# Línea 581: 320 valores
# Línea 582: 320 valores
# Línea 583: 320 valores
# Línea 584: 320 valores
# Línea 585: 320 valores
# Línea 586: 320 valores
# Línea 587: 320 valores
# Línea 588: 320 valores
# Línea 589: 320 valores
# Línea 590: 320 valores
# Línea 591: 320 valores
# Línea 592: 320 valores
# Línea 593: 320 valores
# Línea 594: 320 valores
# Línea 595: 320 valores
# Línea 596: 320 valores
# Línea 597: 320 valores
# Línea 598: 320 valores
# Línea 599: 320 valores
# Línea 600: 320 valores
# Línea 601: 320 valores
# Línea 602: 320 valores
# Línea 603: 320 valores
# Línea 604: 320 valores
# Línea 605: 320 valores
# Línea 606: 320 valores
# Línea 607: 320 valores
# Línea 608: 320 valores
# Línea 609: 320 valores
# Línea 610: 320 valores
# Línea 611: 320 valores
# Línea 612: 320 valores
# Línea 613: 320 valores
# Línea 614: 320 valores
# Línea 615: 320 valores
# Línea 616: 320 valores
# Línea 617: 320 valores
# Línea 618: 320 valores
# Línea 619: 320 valores
# Línea 620: 320 valores
# Línea 621: 320 valores
# Línea 622: 320 valores
# Línea 623: 320 valores
# Línea 624: 320 valores
# Línea 625: 320 valores
# Línea 626: 320 valores
# Línea 627: 320 valores
# Línea 628: 320 valores
# Línea 629: 320 valores
# Línea 630: 320 valores
# Línea 631: 320 valores
# Línea 632: 320 valores
# Línea 633: 320 valores
# Línea 634: 320 valores
# Línea 635: 320 valores
# Línea 636: 320 valores
# Línea 637: 320 valores
# Línea 638: 320 valores
# Línea 639: 320 valores
# Línea 640: 320 valores
# Línea 641: 320 valores
# Línea 642: vacía, ignorada
# Línea 643: 320 valores
# Línea 644: 320 valores
# Línea 645: 320 valores
# Línea 646: 320 valores
# Línea 647: 320 valores
# Línea 648: 320 valores
# Línea 649: 320 valores
# Línea 650: 320 valores
# Línea 651: 320 valores
# Línea 652: 320 valores
# Línea 653: 320 valores
# Línea 654: 320 valores
# Línea 655: 320 valores
# Línea 656: 320 valores
# Línea 657: 320 valores
# Línea 658: 320 valores
# Línea 659: 320 valores
# Línea 660: 320 valores
# Línea 661: 320 valores
# Línea 662: 320 valores
# Línea 663: 320 valores
# Línea 664: 320 valores
# Línea 665: 320 valores
# Línea 666: 320 valores
# Línea 667: 320 valores
# Línea 668: 320 valores
# Línea 669: 320 valores
# Línea 670: 320 valores
# Línea 671: 320 valores
# Línea 672: 320 valores
# Línea 673: 320 valores
# Línea 674: 320 valores
# Línea 675: 320 valores
# Línea 676: 320 valores
# Línea 677: 320 valores
# Línea 678: 320 valores
# Línea 679: 320 valores
# Línea 680: 320 valores
# Línea 681: 320 valores
# Línea 682: 320 valores
# Línea 683: 320 valores
# Línea 684: 320 valores
# Línea 685: 320 valores
# Línea 686: 320 valores
# Línea 687: 320 valores
# Línea 688: 320 valores
# Línea 689: 320 valores
# Línea 690: 320 valores
# Línea 691: 320 valores
# Línea 692: 320 valores
# Línea 693: 320 valores
# Línea 694: 320 valores
# Línea 695: 320 valores
# Línea 696: 320 valores
# Línea 697: 320 valores
# Línea 698: 320 valores
# Línea 699: 320 valores
# Línea 700: 320 valores
# Línea 701: 320 valores
# Línea 702: 320 valores
# Línea 703: 320 valores
# Línea 704: 320 valores
# Línea 705: 320 valores
# Línea 706: 320 valores
# Línea 707: 320 valores
# Línea 708: 320 valores
# Línea 709: 320 valores
# Línea 710: 320 valores
# Línea 711: 320 valores
# Línea 712: 320 valores
# Línea 713: 320 valores
# Línea 714: 320 valores
# Línea 715: 320 valores
# Línea 716: 320 valores
# Línea 717: 320 valores
# Línea 718: 320 valores
# Línea 719: 320 valores
# Línea 720: 320 valores
# Línea 721: 320 valores
# Línea 722: 320 valores
# Línea 723: 320 valores
# Línea 724: 320 valores
# Línea 725: 320 valores
# Línea 726: 320 valores
# Línea 727: 320 valores
# Línea 728: 320 valores
# Línea 729: 320 valores
# Línea 730: 320 valores
# Línea 731: 320 valores
# Línea 732: 320 valores
# Línea 733: 320 valores
# Línea 734: 320 valores
# Línea 735: 320 valores
# Línea 736: 320 valores
# Línea 737: 320 valores
# Línea 738: 320 valores
# Línea 739: 320 valores
# Línea 740: 320 valores
# Línea 741: 320 valores
# Línea 742: 320 valores
# Línea 743: 320 valores
# Línea 744: 320 valores
# Línea 745: 320 valores
# Línea 746: 320 valores
# Línea 747: 320 valores
# Línea 748: 320 valores
# Línea 749: 320 valores
# Línea 750: 320 valores
# Línea 751: 320 valores
# Línea 752: 320 valores
# Línea 753: 320 valores
# Línea 754: 320 valores
# Línea 755: 320 valores
# Línea 756: 320 valores
# Línea 757: 320 valores
# Línea 758: 320 valores
# Línea 759: 320 valores
# Línea 760: 320 valores
# Línea 761: 320 valores
# Línea 762: 320 valores
# Línea 763: 320 valores
# Línea 764: 320 valores
# Línea 765: 320 valores
# Línea 766: 320 valores
# Línea 767: 320 valores
# Línea 768: 320 valores
# Línea 769: 320 valores
# Línea 770: 320 valores
# Línea 771: 320 valores
# Línea 772: 320 valores
# Línea 773: 320 valores
# Línea 774: 320 valores
# Línea 775: 320 valores
# Línea 776: 320 valores
# Línea 777: 320 valores
# Línea 778: 320 valores
# Línea 779: 320 valores
# Línea 780: 320 valores
# Línea 781: 320 valores
# Línea 782: 320 valores
# Línea 783: 320 valores
# Línea 784: 320 valores
# Línea 785: 320 valores
# Línea 786: 320 valores
# Línea 787: 320 valores
# Línea 788: 320 valores
# Línea 789: 320 valores
# Línea 790: 320 valores
# Línea 791: 320 valores
# Línea 792: 320 valores
# Línea 793: 320 valores
# Línea 794: 320 valores
# Línea 795: 320 valores
# Línea 796: 320 valores
# Línea 797: 320 valores
# Línea 798: 320 valores
# Línea 799: 320 valores
# Línea 800: 320 valores
# Línea 801: 320 valores
# Línea 802: 320 valores
# Línea 803: 320 valores
# Línea 804: 320 valores
# Línea 805: 320 valores
# Línea 806: 320 valores
# Línea 807: 320 valores
# Línea 808: 320 valores
# Línea 809: 320 valores
# Línea 810: 320 valores
# Línea 811: 320 valores
# Línea 812: 320 valores
# Línea 813: 320 valores
# Línea 814: 320 valores
# Línea 815: 320 valores
# Línea 816: 320 valores
# Línea 817: 320 valores
# Línea 818: 320 valores
# Línea 819: 320 valores
# Línea 820: 320 valores
# Línea 821: 320 valores
# Línea 822: 320 valores
# Línea 823: 320 valores
# Línea 824: 320 valores
# Línea 825: 320 valores
# Línea 826: 320 valores
# Línea 827: 320 valores
# Línea 828: 320 valores
# Línea 829: 320 valores
# Línea 830: 320 valores
# Línea 831: 320 valores
# Línea 832: 320 valores
# Línea 833: 320 valores
# Línea 834: 320 valores
# Línea 835: 320 valores
# Línea 836: 320 valores
# Línea 837: 320 valores
# Línea 838: 320 valores
# Línea 839: 320 valores
# Línea 840: 320 valores
# Línea 841: 320 valores
# Línea 842: 320 valores
# Línea 843: 320 valores
# Línea 844: 320 valores
# Línea 845: 320 valores
# Línea 846: 320 valores
# Línea 847: 320 valores
# Línea 848: 320 valores
# Línea 849: 320 valores
# Línea 850: 320 valores
# Línea 851: 320 valores
# Línea 852: 320 valores
# Línea 853: 320 valores
# Línea 854: 320 valores
# Línea 855: 320 valores
# Línea 856: 320 valores
# Línea 857: 320 valores
# Línea 858: 320 valores
# Línea 859: 320 valores
# Línea 860: 320 valores
# Línea 861: 320 valores
# Línea 862: 320 valores
# Línea 863: 320 valores
# Línea 864: 320 valores
# Línea 865: 320 valores
# Línea 866: 320 valores
# Línea 867: 320 valores
# Línea 868: 320 valores
# Línea 869: 320 valores
# Línea 870: 320 valores
# Línea 871: 320 valores
# Línea 872: 320 valores
# Línea 873: 320 valores
# Línea 874: 320 valores
# Línea 875: 320 valores
# Línea 876: 320 valores
# Línea 877: 320 valores
# Línea 878: 320 valores
# Línea 879: 320 valores
# Línea 880: 320 valores
# Línea 881: 320 valores
# Línea 882: 320 valores
# Línea 883: 320 valores
# Línea 884: 320 valores
# Línea 885: 320 valores
# Línea 886: 320 valores
# Línea 887: 320 valores
# Línea 888: 320 valores
# Línea 889: 320 valores
# Línea 890: 320 valores
# Línea 891: 320 valores
# Línea 892: 320 valores
# Línea 893: 320 valores
# Línea 894: 320 valores
# Línea 895: 320 valores
# Línea 896: 320 valores
# Línea 897: 320 valores
# Línea 898: 320 valores
# Línea 899: 320 valores
# Línea 900: 320 valores
# Línea 901: 320 valores
# Línea 902: 320 valores
# Línea 903: 320 valores
# Línea 904: 320 valores
# Línea 905: 320 valores
# Línea 906: 320 valores
# Línea 907: 320 valores
# Línea 908: 320 valores
# Línea 909: 320 valores
# Línea 910: 320 valores
# Línea 911: 320 valores
# Línea 912: 320 valores
# Línea 913: 320 valores
# Línea 914: 320 valores
# Línea 915: 320 valores
# Línea 916: 320 valores
# Línea 917: 320 valores
# Línea 918: 320 valores
# Línea 919: 320 valores
# Línea 920: 320 valores
# Línea 921: 320 valores
# Línea 922: 320 valores
# Línea 923: 320 valores
# Línea 924: 320 valores
# Línea 925: 320 valores
# Línea 926: 320 valores
# Línea 927: 320 valores
# Línea 928: 320 valores
# Línea 929: 320 valores
# Línea 930: 320 valores
# Línea 931: 320 valores
# Línea 932: 320 valores
# Línea 933: 320 valores
# Línea 934: 320 valores
# Línea 935: 320 valores
# Línea 936: 320 valores
# Línea 937: 320 valores
# Línea 938: 320 valores
# Línea 939: 320 valores
# Línea 940: 320 valores
# Línea 941: 320 valores
# Línea 942: 320 valores
# Línea 943: 320 valores
# Línea 944: 320 valores
# Línea 945: 320 valores
# Línea 946: 320 valores
# Línea 947: 320 valores
# Línea 948: 320 valores
# Línea 949: 320 valores
# Línea 950: 320 valores
# Línea 951: 320 valores
# Línea 952: 320 valores
# Línea 953: 320 valores
# Línea 954: 320 valores
# Línea 955: 320 valores
# Línea 956: 320 valores
# Línea 957: 320 valores
# Línea 958: 320 valores
# Línea 959: 320 valores
# Línea 960: 320 valores
# Línea 961: 320 valores
# Línea 962: 320 valores
# Línea 963: vacía, ignorada
# Línea 964: 320 valores
# Línea 965: 320 valores
# Línea 966: 320 valores
# Línea 967: 320 valores
# Línea 968: 320 valores
# Línea 969: 320 valores
# Línea 970: 320 valores
# Línea 971: 320 valores
# Línea 972: 320 valores
# Línea 973: 320 valores
# Línea 974: 320 valores
# Línea 975: 320 valores
# Línea 976: 320 valores
# Línea 977: 320 valores
# Línea 978: 320 valores
# Línea 979: 320 valores
# Línea 980: 320 valores
# Línea 981: 320 valores
# Línea 982: 320 valores
# Línea 983: 320 valores
# Línea 984: 320 valores
# Línea 985: 320 valores
# Línea 986: 320 valores
# Línea 987: 320 valores
# Línea 988: 320 valores
# Línea 989: 320 valores
# Línea 990: 320 valores
# Línea 991: 320 valores
# Línea 992: 320 valores
# Línea 993: 320 valores
# Línea 994: 320 valores
# Línea 995: 320 valores
# Línea 996: 320 valores
# Línea 997: 320 valores
# Línea 998: 320 valores
# Línea 999: 320 valores
# Línea 1000: 320 valores
# Línea 1001: 320 valores
# Línea 1002: 320 valores
# Línea 1003: 320 valores
# Línea 1004: 320 valores
# Línea 1005: 320 valores
# Línea 1006: 320 valores
# Línea 1007: 320 valores
# Línea 1008: 320 valores
# Línea 1009: 320 valores
# Línea 1010: 320 valores
# Línea 1011: 320 valores
# Línea 1012: 320 valores
# Línea 1013: 320 valores
# Línea 1014: 320 valores
# Línea 1015: 320 valores
# Línea 1016: 320 valores
# Línea 1017: 320 valores
# Línea 1018: 320 valores
# Línea 1019: 320 valores
# Línea 1020: 320 valores
# Línea 1021: 320 valores
# Línea 1022: 320 valores
# Línea 1023: 320 valores
# Línea 1024: 320 valores
# Línea 1025: 320 valores
# Línea 1026: 320 valores
# Línea 1027: 320 valores
# Línea 1028: 320 valores
# Línea 1029: 320 valores
# Línea 1030: 320 valores
# Línea 1031: 320 valores
# Línea 1032: 320 valores
# Línea 1033: 320 valores
# Línea 1034: 320 valores
# Línea 1035: 320 valores
# Línea 1036: 320 valores
# Línea 1037: 320 valores
# Línea 1038: 320 valores
# Línea 1039: 320 valores
# Línea 1040: 320 valores
# Línea 1041: 320 valores
# Línea 1042: 320 valores
# Línea 1043: 320 valores
# Línea 1044: 320 valores
# Línea 1045: 320 valores
# Línea 1046: 320 valores
# Línea 1047: 320 valores
# Línea 1048: 320 valores
# Línea 1049: 320 valores
# Línea 1050: 320 valores
# Línea 1051: 320 valores
# Línea 1052: 320 valores
# Línea 1053: 320 valores
# Línea 1054: 320 valores
# Línea 1055: 320 valores
# Línea 1056: 320 valores
# Línea 1057: 320 valores
# Línea 1058: 320 valores
# Línea 1059: 320 valores
# Línea 1060: 320 valores
# Línea 1061: 320 valores
# Línea 1062: 320 valores
# Línea 1063: 320 valores
# Línea 1064: 320 valores
# Línea 1065: 320 valores
# Línea 1066: 320 valores
# Línea 1067: 320 valores
# Línea 1068: 320 valores
# Línea 1069: 320 valores
# Línea 1070: 320 valores
# Línea 1071: 320 valores
# Línea 1072: 320 valores
# Línea 1073: 320 valores
# Línea 1074: 320 valores
# Línea 1075: 320 valores
# Línea 1076: 320 valores
# Línea 1077: 320 valores
# Línea 1078: 320 valores
# Línea 1079: 320 valores
# Línea 1080: 320 valores
# Línea 1081: 320 valores
# Línea 1082: 320 valores
# Línea 1083: 320 valores
# Línea 1084: 320 valores
# Línea 1085: 320 valores
# Línea 1086: 320 valores
# Línea 1087: 320 valores
# Línea 1088: 320 valores
# Línea 1089: 320 valores
# Línea 1090: 320 valores
# Línea 1091: 320 valores
# Línea 1092: 320 valores
# Línea 1093: 320 valores
# Línea 1094: 320 valores
# Línea 1095: 320 valores
# Línea 1096: 320 valores
# Línea 1097: 320 valores
# Línea 1098: 320 valores
# Línea 1099: 320 valores
# Línea 1100: 320 valores
# Línea 1101: 320 valores
# Línea 1102: 320 valores
# Línea 1103: 320 valores
# Línea 1104: 320 valores
# Línea 1105: 320 valores
# Línea 1106: 320 valores
# Línea 1107: 320 valores
# Línea 1108: 320 valores
# Línea 1109: 320 valores
# Línea 1110: 320 valores
# Línea 1111: 320 valores
# Línea 1112: 320 valores
# Línea 1113: 320 valores
# Línea 1114: 320 valores
# Línea 1115: 320 valores
# Línea 1116: 320 valores
# Línea 1117: 320 valores
# Línea 1118: 320 valores
# Línea 1119: 320 valores
# Línea 1120: 320 valores
# Línea 1121: 320 valores
# Línea 1122: 320 valores
# Línea 1123: 320 valores
# Línea 1124: 320 valores
# Línea 1125: 320 valores
# Línea 1126: 320 valores
# Línea 1127: 320 valores
# Línea 1128: 320 valores
# Línea 1129: 320 valores
# Línea 1130: 320 valores
# Línea 1131: 320 valores
# Línea 1132: 320 valores
# Línea 1133: 320 valores
# Línea 1134: 320 valores
# Línea 1135: 320 valores
# Línea 1136: 320 valores
# Línea 1137: 320 valores
# Línea 1138: 320 valores
# Línea 1139: 320 valores
# Línea 1140: 320 valores
# Línea 1141: 320 valores
# Línea 1142: 320 valores
# Línea 1143: 320 valores
# Línea 1144: 320 valores
# Línea 1145: 320 valores
# Línea 1146: 320 valores
# Línea 1147: 320 valores
# Línea 1148: 320 valores
# Línea 1149: 320 valores
# Línea 1150: 320 valores
# Línea 1151: 320 valores
# Línea 1152: 320 valores
# Línea 1153: 320 valores
# Línea 1154: 320 valores
# Línea 1155: 320 valores
# Línea 1156: 320 valores
# Línea 1157: 320 valores
# Línea 1158: 320 valores
# Línea 1159: 320 valores
# Línea 1160: 320 valores
# Línea 1161: 320 valores
# Línea 1162: 320 valores
# Línea 1163: 320 valores
# Línea 1164: 320 valores
# Línea 1165: 320 valores
# Línea 1166: 320 valores
# Línea 1167: 320 valores
# Línea 1168: 320 valores
# Línea 1169: 320 valores
# Línea 1170: 320 valores
# Línea 1171: 320 valores
# Línea 1172: 320 valores
# Línea 1173: 320 valores
# Línea 1174: 320 valores
# Línea 1175: 320 valores
# Línea 1176: 320 valores
# Línea 1177: 320 valores
# Línea 1178: 320 valores
# Línea 1179: 320 valores
# Línea 1180: 320 valores
# Línea 1181: 320 valores
# Línea 1182: 320 valores
# Línea 1183: 320 valores
# Línea 1184: 320 valores
# Línea 1185: 320 valores
# Línea 1186: 320 valores
# Línea 1187: 320 valores
# Línea 1188: 320 valores
# Línea 1189: 320 valores
# Línea 1190: 320 valores
# Línea 1191: 320 valores
# Línea 1192: 320 valores
# Línea 1193: 320 valores
# Línea 1194: 320 valores
# Línea 1195: 320 valores
# Línea 1196: 320 valores
# Línea 1197: 320 valores
# Línea 1198: 320 valores
# Línea 1199: 320 valores
# Línea 1200: 320 valores
# Línea 1201: 320 valores
# Línea 1202: 320 valores
# Línea 1203: 320 valores
# Línea 1204: 320 valores
# Línea 1205: 320 valores
# Línea 1206: 320 valores
# Línea 1207: 320 valores
# Línea 1208: 320 valores
# Línea 1209: 320 valores
# Línea 1210: 320 valores
# Línea 1211: 320 valores
# Línea 1212: 320 valores
# Línea 1213: 320 valores
# Línea 1214: 320 valores
# Línea 1215: 320 valores
# Línea 1216: 320 valores
# Línea 1217: 320 valores
# Línea 1218: 320 valores
# Línea 1219: 320 valores
# Línea 1220: 320 valores
# Línea 1221: 320 valores
# Línea 1222: 320 valores
# Línea 1223: 320 valores
# Línea 1224: 320 valores
# Línea 1225: 320 valores
# Línea 1226: 320 valores
# Línea 1227: 320 valores
# Línea 1228: 320 valores
# Línea 1229: 320 valores
# Línea 1230: 320 valores
# Línea 1231: 320 valores
# Línea 1232: 320 valores
# Línea 1233: 320 valores
# Línea 1234: 320 valores
# Línea 1235: 320 valores
# Línea 1236: 320 valores
# Línea 1237: 320 valores
# Línea 1238: 320 valores
# Línea 1239: 320 valores
# Línea 1240: 320 valores
# Línea 1241: 320 valores
# Línea 1242: 320 valores
# Línea 1243: 320 valores
# Línea 1244: 320 valores
# Línea 1245: 320 valores
# Línea 1246: 320 valores
# Línea 1247: 320 valores
# Línea 1248: 320 valores
# Línea 1249: 320 valores
# Línea 1250: 320 valores
# Línea 1251: 320 valores
# Línea 1252: 320 valores
# Línea 1253: 320 valores
# Línea 1254: 320 valores
# Línea 1255: 320 valores
# Línea 1256: 320 valores
# Línea 1257: 320 valores
# Línea 1258: 320 valores
# Línea 1259: 320 valores
# Línea 1260: 320 valores
# Línea 1261: 320 valores
# Línea 1262: 320 valores
# Línea 1263: 320 valores
# Línea 1264: 320 valores
# Línea 1265: 320 valores
# Línea 1266: 320 valores
# Línea 1267: 320 valores
# Línea 1268: 320 valores
# Línea 1269: 320 valores
# Línea 1270: 320 valores
# Línea 1271: 320 valores
# Línea 1272: 320 valores
# Línea 1273: 320 valores
# Línea 1274: 320 valores
# Línea 1275: 320 valores
# Línea 1276: 320 valores
# Línea 1277: 320 valores
# Línea 1278: 320 valores
# Línea 1279: 320 valores
# Línea 1280: 320 valores
# Línea 1281: 320 valores
# Línea 1282: 320 valores
# Línea 1283: 320 valores
# Línea 1284: vacía, ignorada
# Total de valores leídos: 409600
# Se leyeron 4 configuraciones
